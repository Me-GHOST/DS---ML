# %% [markdown]
#  # **NumPy Arrays**

# %%
import numpy as np

# %%
c = [[1,2,3],[4,5,6],[7,8,9]]
a = np.array(c)
a

# %%
np.arange(0, 12, 2)

# %%
np.zeros((3,4))

# %%
np.ones((4,4))

# %%
np.linspace(0,4,6)

# %%
np.eye(4)

# %%
np.eye(3)

# %%
np.random.rand(5)

# %%
np.random.randn(2,2)

# %%
np.random.randint(1, 11, 10)

# %%
arr = np. arange(25)

# %%
ranarr = np.random.randint(1,51,25)
ranarr

# %%
rashaped_arr = ranarr.reshape(5,5)
rashaped_arr

# %%
arr

# %%
ranarr.max()
# Out:
# 45

# %%
ranarr.min()
# Out:
# 6

# %%
#to know the index of max value
ranarr.argmax()
# Out:
# 18

# %%
#to know the index of min value
ranarr.argmin()
# Out:
# 15

# %%
#to know the shape of any vector/arr
arr.shape
#it's aa 1D vector so....
# Out:
# (25,)

# %%
#let's make it 2D vactor   :)
arr1 = arr.reshape(5,5)
arr1.shape
# Out:
# (5, 5)

# %%
arr.dtype
# Out:
# dtype('int64')
