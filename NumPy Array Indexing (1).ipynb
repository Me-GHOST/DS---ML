# %% [markdown]
# # **NumPy Array and Indexing**

# %%
import numpy as np

# %%
arr = np.arange(0,11)
arr

# %%
arr[1:5]

# %%
arr[5:]

# %%
arr[:6]

# %%
arr[:]

# %%
arr_2d = np.array([[12,23,34],[45,56,67],[78,89,90]])

# %%
arr_2d

# %%
arr_2d[2][1]
# Out:
# 89

# %%
arr_2d[2,1]
# Out:
# 89

# %%
arr_2d[1:,1:]

# %%
arr1 = np.arange(1,11)

# %%
bool_arr = arr1 < 7

# %%
bool_arr

# %%
arr1[bool_arr]

# %%
arr1[arr1 >5]

# %%
arr1[arr1<3]

# %%
_2darr = np.arange(50).reshape(10, 5)
_2darr

# %%
_2darr[4:8,3:]

# %% [markdown]
# # Good Job
